# %%
import numpy as np
import pandas as pd
from sklearn import model_selection

# %%
df_train = pd.read_csv('../input/tabular-playground-series-sep-2021/train.csv')

# %%
df_train['KFold'] = -1

# %%
df_train.head()
# Out:
#    id       f1        f2         f3        f4       f5        f6       f7  \
# 0   0  0.10859  0.004314    -37.566  0.017364  0.28915 -10.25100   135.12
# 1   1  0.10090  0.299610  11822.000  0.276500  0.45970  -0.83733  1721.90
# 2   2  0.17803 -0.006980    907.270  0.272140  0.45948   0.17327  2298.00
# 3   3  0.15236  0.007259    780.100  0.025179  0.51947   7.49140   112.51
# 4   4  0.11623  0.502900   -109.150  0.297910  0.34490  -0.40932  2538.90
#
#          f8            f9  ...    f111     f112      f113      f114    f115  \
# 0  168900.0  3.992400e+14  ...  1.7482  1.90960  -7.11570   4378.80  1.2096
# 1  119810.0  3.874100e+15  ...  4.1684  0.34808   4.14200    913.23  1.2464
# 2  360650.0  1.224500e+13  ...  1.2042  0.26290   8.13120  45119.00  1.1764
# 3  259490.0  7.781400e+13  ...  2.0694  0.79631 -16.33600   4952.40  1.1784
# 4   65332.0  1.907200e+15  ...  1.5298  1.14640  -0.43124   3856.50  1.4830
#
#            f116    f117     f118  claim  KFold
# 0  8.613400e+14   140.1  1.01770      1     -1
# 1  7.575100e+15  1861.0  0.28359      0     -1
# 2  3.218100e+14  3838.2  0.40690      1     -1
# 3  4.533000e+12  4889.1  0.51486      1     -1
# 4 -8.991300e+12     NaN  0.23049      1     -1
#
# [5 rows x 121 columns]

# %%
kf = model_selection.KFold(n_splits = 5, shuffle = True, random_state = 42)

# %%
for fold, (train_indicies, valid_indicies) in enumerate (kf.split(df_train)):
    print(fold, len(train_indicies), len(valid_indicies))
    df_train.loc[valid_indicies, "KFold"] = fold
# Out:
# 0 766335 191584
# 1 766335 191584
# 2 766335 191584
# 3 766335 191584
# 4 766336 191583

# %%
df_train.loc[train_indicies, ["KFold"]]
# Out:
#         KFold
# 0           0
# 1           3
# 2           1
# 4           3
# 6           1
# ...       ...
# 957911      0
# 957914      2
# 957916      0
# 957917      0
# 957918      2
#
# [766336 rows x 1 columns]

# %%
df_train.to_csv('train_folds.csv', index = False)

# %%
df = pd.read_csv('train_folds.csv')

# %%
df.head()
# Out:
#    id       f1        f2         f3        f4       f5        f6       f7  \
# 0   0  0.10859  0.004314    -37.566  0.017364  0.28915 -10.25100   135.12
# 1   1  0.10090  0.299610  11822.000  0.276500  0.45970  -0.83733  1721.90
# 2   2  0.17803 -0.006980    907.270  0.272140  0.45948   0.17327  2298.00
# 3   3  0.15236  0.007259    780.100  0.025179  0.51947   7.49140   112.51
# 4   4  0.11623  0.502900   -109.150  0.297910  0.34490  -0.40932  2538.90
#
#          f8            f9  ...    f111     f112      f113      f114    f115  \
# 0  168900.0  3.992400e+14  ...  1.7482  1.90960  -7.11570   4378.80  1.2096
# 1  119810.0  3.874100e+15  ...  4.1684  0.34808   4.14200    913.23  1.2464
# 2  360650.0  1.224500e+13  ...  1.2042  0.26290   8.13120  45119.00  1.1764
# 3  259490.0  7.781400e+13  ...  2.0694  0.79631 -16.33600   4952.40  1.1784
# 4   65332.0  1.907200e+15  ...  1.5298  1.14640  -0.43124   3856.50  1.4830
#
#            f116    f117     f118  claim  KFold
# 0  8.613400e+14   140.1  1.01770      1      0
# 1  7.575100e+15  1861.0  0.28359      0      3
# 2  3.218100e+14  3838.2  0.40690      1      1
# 3  4.533000e+12  4889.1  0.51486      1      4
# 4 -8.991300e+12     NaN  0.23049      1      3
#
# [5 rows x 121 columns]
